# %% [markdown]
# # Random Forest model

# %% [markdown]
# Add main directory to path to access utils folder

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(parent_dir)

# %% [markdown]
# import modules

# %%
import numpy as np
import optuna
import pandas as pd
from sklearn import set_config
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from utils.machine_learning import Rounder

# %%
train_data = pd.read_pickle("../../data/train_processed.pkl")
train_data
# Out:
#      PassengerNum   Age HomePlanet    Destination CabinDeck CabinSide  \
# 0              01  39.0     Europa    TRAPPIST-1e         B         P
# 1              01  24.0      Earth    TRAPPIST-1e         F         S
# 2              01  58.0     Europa    TRAPPIST-1e         A         S
# 3              02  33.0     Europa    TRAPPIST-1e         A         S
# 4              01  16.0      Earth    TRAPPIST-1e         F         S
# ...           ...   ...        ...            ...       ...       ...
# 8688           01  41.0     Europa    55 Cancri e         A         P
# 8689           01  18.0      Earth  PSO J318.5-22         G         S
# 8690           01  26.0      Earth    TRAPPIST-1e         G         S
# 8691           01  32.0     Europa    55 Cancri e         E         S
# 8692           02  44.0     Europa    TRAPPIST-1e         E         S
#
#      CryoSleep    VIP  RoomService  FoodCourt  ...  YesShoppingMall  YesSpa  \
# 0        False  False          0.0        0.0  ...            False   False
# 1        False  False        109.0        9.0  ...             True    True
# 2        False   True         43.0     3576.0  ...            False    True
# 3        False  False          0.0     1283.0  ...             True    True
# 4        False  False        303.0       70.0  ...             True    True
# ...        ...    ...          ...        ...  ...              ...     ...
# 8688     False   True          0.0     6819.0  ...            False    True
# 8689      True  False          0.0        0.0  ...            False   False
# 8690     False  False          0.0        0.0  ...             True    True
# 8691     False  False          0.0     1049.0  ...            False    True
# 8692     False  False        126.0     4688.0  ...            False   False
#
#       YesVRDeck YesTotalSpending LogRoomService LogFoodCourt LogShoppingMall  \
# 0         False            False       0.000000     0.000000        0.000000
# 1          True             True       4.700480     2.302585        3.258097
# 2          True             True       3.784190     8.182280        0.000000
# 3          True             True       0.000000     7.157735        5.918894
# 4          True             True       5.717028     4.262680        5.023881
# ...         ...              ...            ...          ...             ...
# 8688       True             True       0.000000     8.827615        0.000000
# 8689      False            False       0.000000     0.000000        0.000000
# 8690      False             True       0.000000     0.000000        7.535297
# 8691       True             True       0.000000     6.956545        0.000000
# 8692       True             True       4.844187     8.452975        0.000000
#
#         LogSpa LogVRDeck LogTotalSpending
# 0     0.000000  0.000000         0.000000
# 1     6.309918  3.806662         6.602588
# 2     8.812248  3.912023         9.248021
# 3     8.110728  5.267858         8.551981
# 4     6.338594  1.098612         6.995766
# ...        ...       ...              ...
# 8688  7.404888  4.317488         9.052165
# 8689  0.000000  0.000000         0.000000
# 8690  0.693147  0.000000         7.535830
# 8691  5.869297  8.082093         8.442039
# 8692  0.000000  2.564949         8.481980
#
# [8693 rows x 36 columns]

# %%
df = train_data.copy()
X = df.drop(
    columns=[
        "Transported",
        "TotalSpending",
        "LogRoomService",
        "LogFoodCourt",
        "LogShoppingMall",
        "LogSpa",
        "LogVRDeck",
        "LogTotalSpending",
        "LogTotalSpending",
    ]
)
y = df["Transported"]
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)

# %%
X_processed = feature_preprocessing.fit_transform(X)

# %%
model = RandomForestClassifier()
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X_processed, y, scoring="accuracy", cv=cv, n_jobs=-1)
mean_acc = np.mean(n_scores)
std_acc = np.std(n_scores)
print(f"Accuracy: {mean_acc:.3f} (std. dev. {std_acc:.3f})")
# Out:
# Accuracy: 0.791 (std. dev. 0.013)

# %%
def objective(trial, data=X_processed, target=y):

    data = data.copy()

    param = {
        "max_depth": trial.suggest_int("max_depth", 2, 32, log=True),
        "criterion": trial.suggest_categorical(
            "criterion", ["gini", "entropy", "log_loss"]
        ),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 32, log=True),
        "max_features": trial.suggest_categorical(
            "max_features", ["sqrt", "log2", None]
        ),
    }

    model = RandomForestClassifier(**param)
    return cross_val_score(
        model, data, target, scoring="accuracy", n_jobs=-1, cv=5
    ).mean()


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

trial = study.best_trial

print("Accuracy: {}".format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2024-10-17 23:38:25,372] A new study created in memory with name: no-name-bf19101a-bde0-4175-a519-e2f2e6bf071c
# [I 2024-10-17 23:38:26,079] Trial 0 finished with value: 0.7364579328489913 and parameters: {'max_depth': 2, 'criterion': 'log_loss', 'min_samples_split': 7, 'max_features': 'log2'}. Best is trial 0 with value: 0.7364579328489913.
# [I 2024-10-17 23:38:31,689] Trial 1 finished with value: 0.7980005836456145 and parameters: {'max_depth': 24, 'criterion': 'entropy', 'min_samples_split': 23, 'max_features': None}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:32,388] Trial 2 finished with value: 0.7368030910718765 and parameters: {'max_depth': 2, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:32,993] Trial 3 finished with value: 0.737493142825758 and parameters: {'max_depth': 3, 'criterion': 'gini', 'min_samples_split': 13, 'max_features': 'log2'}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:34,034] Trial 4 finished with value: 0.7848861593273121 and parameters: {'max_depth': 8, 'criterion': 'log_loss', 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:38,616] Trial 5 finished with value: 0.7952405089760328 and parameters: {'max_depth': 15, 'criterion': 'gini', 'min_samples_split': 22, 'max_features': None}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:43,033] Trial 6 finished with value: 0.790179335371902 and parameters: {'max_depth': 7, 'criterion': 'log_loss', 'min_samples_split': 26, 'max_features': None}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:44,187] Trial 7 finished with value: 0.7182813423319752 and parameters: {'max_depth': 2, 'criterion': 'entropy', 'min_samples_split': 18, 'max_features': None}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:45,456] Trial 8 finished with value: 0.7873013404658974 and parameters: {'max_depth': 24, 'criterion': 'gini', 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:46,664] Trial 9 finished with value: 0.7909835355027922 and parameters: {'max_depth': 22, 'criterion': 'log_loss', 'min_samples_split': 18, 'max_features': 'log2'}. Best is trial 1 with value: 0.7980005836456145.
# [I 2024-10-17 23:38:51,519] Trial 10 finished with value: 0.7989201894399848 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 10 with value: 0.7989201894399848.
# [I 2024-10-17 23:38:56,203] Trial 11 finished with value: 0.7969646457661539 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 10 with value: 0.7989201894399848.
# [I 2024-10-17 23:39:02,111] Trial 12 finished with value: 0.7994952987411916 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:06,683] Trial 13 finished with value: 0.7929382189279847 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:08,659] Trial 14 finished with value: 0.770278674237737 and parameters: {'max_depth': 4, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:11,166] Trial 15 finished with value: 0.7843125720044654 and parameters: {'max_depth': 5, 'criterion': 'entropy', 'min_samples_split': 3, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:12,788] Trial 16 finished with value: 0.7963898673298081 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 11, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:20,914] Trial 17 finished with value: 0.7909817488325432 and parameters: {'max_depth': 31, 'criterion': 'entropy', 'min_samples_split': 3, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:25,551] Trial 18 finished with value: 0.7958147580286012 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:26,227] Trial 19 finished with value: 0.7544029841363534 and parameters: {'max_depth': 5, 'criterion': 'gini', 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:31,654] Trial 20 finished with value: 0.7938580894142435 and parameters: {'max_depth': 18, 'criterion': 'entropy', 'min_samples_split': 3, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:36,967] Trial 21 finished with value: 0.7947788863221128 and parameters: {'max_depth': 31, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:43,212] Trial 22 finished with value: 0.797540549143027 and parameters: {'max_depth': 21, 'criterion': 'entropy', 'min_samples_split': 32, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:47,984] Trial 23 finished with value: 0.7896027702653072 and parameters: {'max_depth': 9, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:54,289] Trial 24 finished with value: 0.798230468550964 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:39:59,529] Trial 25 finished with value: 0.7983449477928335 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:02,672] Trial 26 finished with value: 0.7871885155483324 and parameters: {'max_depth': 6, 'criterion': 'entropy', 'min_samples_split': 3, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:07,730] Trial 27 finished with value: 0.7947788863221128 and parameters: {'max_depth': 17, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:08,730] Trial 28 finished with value: 0.7930550803968526 and parameters: {'max_depth': 13, 'criterion': 'log_loss', 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:09,522] Trial 29 finished with value: 0.77924974407603 and parameters: {'max_depth': 7, 'criterion': 'gini', 'min_samples_split': 6, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:10,347] Trial 30 finished with value: 0.7869577703943446 and parameters: {'max_depth': 10, 'criterion': 'log_loss', 'min_samples_split': 4, 'max_features': 'log2'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:17,563] Trial 31 finished with value: 0.7985748988711553 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:21,625] Trial 32 finished with value: 0.7910982132635781 and parameters: {'max_depth': 9, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:28,303] Trial 33 finished with value: 0.7955842113935299 and parameters: {'max_depth': 17, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:33,349] Trial 34 finished with value: 0.7971948615363644 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:39,495] Trial 35 finished with value: 0.7962745940122724 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:40,940] Trial 36 finished with value: 0.7852314498961415 and parameters: {'max_depth': 8, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:46,624] Trial 37 finished with value: 0.7978847809443016 and parameters: {'max_depth': 20, 'criterion': 'gini', 'min_samples_split': 11, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:49,413] Trial 38 finished with value: 0.7885687514020399 and parameters: {'max_depth': 6, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:50,650] Trial 39 finished with value: 0.7749936970244 and parameters: {'max_depth': 8, 'criterion': 'log_loss', 'min_samples_split': 3, 'max_features': 'log2'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:40:56,238] Trial 40 finished with value: 0.7986901060157188 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:01,020] Trial 41 finished with value: 0.7973101348539001 and parameters: {'max_depth': 16, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:05,455] Trial 42 finished with value: 0.7981153275793729 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:12,087] Trial 43 finished with value: 0.798229674475298 and parameters: {'max_depth': 26, 'criterion': 'entropy', 'min_samples_split': 14, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:17,704] Trial 44 finished with value: 0.798920983515651 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:22,828] Trial 45 finished with value: 0.7938585526250487 and parameters: {'max_depth': 19, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:27,579] Trial 46 finished with value: 0.7951250371395806 and parameters: {'max_depth': 14, 'criterion': 'gini', 'min_samples_split': 11, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:29,017] Trial 47 finished with value: 0.7913284952067607 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 14, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:30,640] Trial 48 finished with value: 0.7915585786310267 and parameters: {'max_depth': 25, 'criterion': 'log_loss', 'min_samples_split': 7, 'max_features': 'log2'}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:32,313] Trial 49 finished with value: 0.7265638162217747 and parameters: {'max_depth': 3, 'criterion': 'entropy', 'min_samples_split': 10, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:35,972] Trial 50 finished with value: 0.7900626062489784 and parameters: {'max_depth': 9, 'criterion': 'entropy', 'min_samples_split': 16, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:40,201] Trial 51 finished with value: 0.7990353965845481 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:47,327] Trial 52 finished with value: 0.7963888747352253 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:52,378] Trial 53 finished with value: 0.7982304685509642 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 12 with value: 0.7994952987411916.
# [I 2024-10-17 23:41:58,540] Trial 54 finished with value: 0.8009915358151286 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:04,181] Trial 55 finished with value: 0.7980003189537259 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 10, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:10,470] Trial 56 finished with value: 0.7961586589650149 and parameters: {'max_depth': 16, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:14,793] Trial 57 finished with value: 0.7962745278393003 and parameters: {'max_depth': 13, 'criterion': 'gini', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:21,346] Trial 58 finished with value: 0.79707932352694 and parameters: {'max_depth': 23, 'criterion': 'entropy', 'min_samples_split': 12, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:22,596] Trial 59 finished with value: 0.7981157907901781 and parameters: {'max_depth': 19, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:25,999] Trial 60 finished with value: 0.7900630694597836 and parameters: {'max_depth': 8, 'criterion': 'entropy', 'min_samples_split': 2, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:31,377] Trial 61 finished with value: 0.8001855490139895 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:37,000] Trial 62 finished with value: 0.7940889669141755 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 10, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:42,200] Trial 63 finished with value: 0.7975400197592494 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:46,560] Trial 64 finished with value: 0.7967355549364706 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:52,991] Trial 65 finished with value: 0.7948944243315372 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:42:53,816] Trial 66 finished with value: 0.7823552416603857 and parameters: {'max_depth': 9, 'criterion': 'log_loss', 'min_samples_split': 8, 'max_features': 'log2'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:00,191] Trial 67 finished with value: 0.7953535324125143 and parameters: {'max_depth': 17, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:03,063] Trial 68 finished with value: 0.7889135787600641 and parameters: {'max_depth': 7, 'criterion': 'entropy', 'min_samples_split': 22, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:07,357] Trial 69 finished with value: 0.7977703678754042 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 12, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:11,947] Trial 70 finished with value: 0.7982308655887972 and parameters: {'max_depth': 11, 'criterion': 'gini', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:16,791] Trial 71 finished with value: 0.7996100426749497 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:21,357] Trial 72 finished with value: 0.7982307332428529 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:28,236] Trial 73 finished with value: 0.795354127969264 and parameters: {'max_depth': 16, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:34,507] Trial 74 finished with value: 0.7974248126146861 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:39,022] Trial 75 finished with value: 0.7922482333470752 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 3, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:40,337] Trial 76 finished with value: 0.796964976631015 and parameters: {'max_depth': 18, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:47,138] Trial 77 finished with value: 0.8000700110045653 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:50,932] Trial 78 finished with value: 0.786728216353856 and parameters: {'max_depth': 6, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:52,139] Trial 79 finished with value: 0.7915593065337208 and parameters: {'max_depth': 12, 'criterion': 'log_loss', 'min_samples_split': 3, 'max_features': 'log2'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:43:58,585] Trial 80 finished with value: 0.7900626724219506 and parameters: {'max_depth': 9, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:06,324] Trial 81 finished with value: 0.7967352240716097 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 10, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:12,629] Trial 82 finished with value: 0.796159783905542 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:19,821] Trial 83 finished with value: 0.7989200570940403 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:27,272] Trial 84 finished with value: 0.7965048097824828 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:34,049] Trial 85 finished with value: 0.7960433194745071 and parameters: {'max_depth': 28, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:40,984] Trial 86 finished with value: 0.7970802499485504 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 4, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:49,857] Trial 87 finished with value: 0.7970805808134114 and parameters: {'max_depth': 21, 'criterion': 'entropy', 'min_samples_split': 28, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:56,626] Trial 88 finished with value: 0.7933989813332663 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 6, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:44:58,261] Trial 89 finished with value: 0.7959302960380256 and parameters: {'max_depth': 12, 'criterion': 'gini', 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:05,067] Trial 90 finished with value: 0.7958135669151021 and parameters: {'max_depth': 17, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:11,150] Trial 91 finished with value: 0.7967343638229714 and parameters: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:17,047] Trial 92 finished with value: 0.7967350255526932 and parameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:24,148] Trial 93 finished with value: 0.7977700370105433 and parameters: {'max_depth': 16, 'criterion': 'entropy', 'min_samples_split': 11, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:30,699] Trial 94 finished with value: 0.8000706727342871 and parameters: {'max_depth': 14, 'criterion': 'entropy', 'min_samples_split': 8, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:36,373] Trial 95 finished with value: 0.7984607504941467 and parameters: {'max_depth': 11, 'criterion': 'entropy', 'min_samples_split': 7, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:44,310] Trial 96 finished with value: 0.7993806871533777 and parameters: {'max_depth': 12, 'criterion': 'entropy', 'min_samples_split': 10, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:51,539] Trial 97 finished with value: 0.7976550283848964 and parameters: {'max_depth': 12, 'criterion': 'log_loss', 'min_samples_split': 10, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:52,706] Trial 98 finished with value: 0.7856919476095345 and parameters: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 13, 'max_features': 'log2'}. Best is trial 54 with value: 0.8009915358151286.
# [I 2024-10-17 23:45:57,437] Trial 99 finished with value: 0.7907533197325818 and parameters: {'max_depth': 9, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}. Best is trial 54 with value: 0.8009915358151286.
# Accuracy: 0.8009915358151286
# Best hyperparameters: {'max_depth': 13, 'criterion': 'entropy', 'min_samples_split': 9, 'max_features': None}

# %%
model = RandomForestClassifier(**study.best_params)
rf_pipeline = Pipeline(
    steps=[("preprocessor", feature_preprocessing), ("model", model)]
)

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
cross_val_score(
    rf_pipeline, X, y, scoring="accuracy", n_jobs=-1, cv=5, error_score="raise"
).mean()
# Out:
# 0.7959291710974986

# %%
import pickle

model = rf_pipeline
model.fit(X, y)

with open(
    "../../ML_models_trained/rf_model.pkl",
    "wb",
) as file:
    pickle.dump(model, file)
