# %% [markdown]
# # PyCaret Models
#
# In this notebook I use an automated machine learning tool named "PyCaret" in order to get a quick idea about what the best models and features are to optimize our prediction of whether passengers were transported to another dimension or not.
#
# In this notebook I take a sort of step-wise approach to deciding which features and models to use moving forward.
#
# I use PyCaret to assess whether all features, logarithmic numeric features only, leaving out logarithmic features, removing the aggregated "total spending" redundancy performs best. This allows me to observe how various models perform differently given these different input feature sets.

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(parent_dir)

# %%
import pandas as pd
from pycaret.classification import ClassificationExperiment
from sklearn import set_config
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from utils.machine_learning import Rounder

# %%
train_data = pd.read_pickle(
    "../../data/train_processed.pkl"
)
train_data
# Out:
#      PassengerNum   Age HomePlanet    Destination CabinDeck CabinSide  \
# 0              01  39.0     Europa    TRAPPIST-1e         B         P
# 1              01  24.0      Earth    TRAPPIST-1e         F         S
# 2              01  58.0     Europa    TRAPPIST-1e         A         S
# 3              02  33.0     Europa    TRAPPIST-1e         A         S
# 4              01  16.0      Earth    TRAPPIST-1e         F         S
# ...           ...   ...        ...            ...       ...       ...
# 8688           01  41.0     Europa    55 Cancri e         A         P
# 8689           01  18.0      Earth  PSO J318.5-22         G         S
# 8690           01  26.0      Earth    TRAPPIST-1e         G         S
# 8691           01  32.0     Europa    55 Cancri e         E         S
# 8692           02  44.0     Europa    TRAPPIST-1e         E         S
#
#      CryoSleep    VIP  RoomService  FoodCourt  ...  YesShoppingMall  YesSpa  \
# 0        False  False          0.0        0.0  ...            False   False
# 1        False  False        109.0        9.0  ...             True    True
# 2        False   True         43.0     3576.0  ...            False    True
# 3        False  False          0.0     1283.0  ...             True    True
# 4        False  False        303.0       70.0  ...             True    True
# ...        ...    ...          ...        ...  ...              ...     ...
# 8688     False   True          0.0     6819.0  ...            False    True
# 8689      True  False          0.0        0.0  ...            False   False
# 8690     False  False          0.0        0.0  ...             True    True
# 8691     False  False          0.0     1049.0  ...            False    True
# 8692     False  False        126.0     4688.0  ...            False   False
#
#       YesVRDeck YesTotalSpending LogRoomService LogFoodCourt LogShoppingMall  \
# 0         False            False       0.000000     0.000000        0.000000
# 1          True             True       4.700480     2.302585        3.258097
# 2          True             True       3.784190     8.182280        0.000000
# 3          True             True       0.000000     7.157735        5.918894
# 4          True             True       5.717028     4.262680        5.023881
# ...         ...              ...            ...          ...             ...
# 8688       True             True       0.000000     8.827615        0.000000
# 8689      False            False       0.000000     0.000000        0.000000
# 8690      False             True       0.000000     0.000000        7.535297
# 8691       True             True       0.000000     6.956545        0.000000
# 8692       True             True       4.844187     8.452975        0.000000
#
#         LogSpa LogVRDeck LogTotalSpending
# 0     0.000000  0.000000         0.000000
# 1     6.309918  3.806662         6.602588
# 2     8.812248  3.912023         9.248021
# 3     8.110728  5.267858         8.551981
# 4     6.338594  1.098612         6.995766
# ...        ...       ...              ...
# 8688  7.404888  4.317488         9.052165
# 8689  0.000000  0.000000         0.000000
# 8690  0.693147  0.000000         7.535830
# 8691  5.869297  8.082093         8.442039
# 8692  0.000000  2.564949         8.481980
#
# [8693 rows x 36 columns]

# %%
train_data.dtypes
# Out:
# PassengerNum           object
# Age                   float64
# HomePlanet             object
# Destination            object
# CabinDeck              object
# CabinSide              object
# CryoSleep              object
# VIP                    object
# RoomService           float64
# FoodCourt             float64
# ShoppingMall          float64
# Spa                   float64
# VRDeck                float64
# Transported            object
# NameMissing            object
# HomeMissing            object
# DestinationMissing     object
# CabinMissing           object
# CryoMissing            object
# VIPMissing             object
# PartySize             float64
# FamilyGroupMember      object
# CabinBin              float64
# TotalSpending         float64
# YesRoomService         object
# YesFoodCourt           object
# YesShoppingMall        object
# YesSpa                 object
# YesVRDeck              object
# YesTotalSpending       object
# LogRoomService        float64
# LogFoodCourt          float64
# LogShoppingMall       float64
# LogSpa                float64
# LogVRDeck             float64
# LogTotalSpending      float64
# dtype: object

# %%
train_data.describe(include="all")
# Out:
#        PassengerNum          Age HomePlanet  Destination CabinDeck CabinSide  \
# count          8693  8514.000000       8693         8693      8693      8693
# unique            8          NaN          4            4         9         3
# top              01          NaN      Earth  TRAPPIST-1e         F         S
# freq           6217          NaN       4602         5915      2794      4288
# mean            NaN    28.827930        NaN          NaN       NaN       NaN
# std             NaN    14.489021        NaN          NaN       NaN       NaN
# min             NaN     0.000000        NaN          NaN       NaN       NaN
# 25%             NaN    19.000000        NaN          NaN       NaN       NaN
# 50%             NaN    27.000000        NaN          NaN       NaN       NaN
# 75%             NaN    38.000000        NaN          NaN       NaN       NaN
# max             NaN    79.000000        NaN          NaN       NaN       NaN
#
#        CryoSleep    VIP   RoomService     FoodCourt  ...  YesShoppingMall  \
# count       8693   8693   8512.000000   8510.000000  ...             8693
# unique         3      3           NaN           NaN  ...                2
# top        False  False           NaN           NaN  ...            False
# freq        5439   8291           NaN           NaN  ...             5795
# mean         NaN    NaN    224.687617    458.077203  ...              NaN
# std          NaN    NaN    666.717663   1611.489240  ...              NaN
# min          NaN    NaN      0.000000      0.000000  ...              NaN
# 25%          NaN    NaN      0.000000      0.000000  ...              NaN
# 50%          NaN    NaN      0.000000      0.000000  ...              NaN
# 75%          NaN    NaN     47.000000     76.000000  ...              NaN
# max          NaN    NaN  14327.000000  29813.000000  ...              NaN
#
#         YesSpa  YesVRDeck YesTotalSpending LogRoomService LogFoodCourt  \
# count     8693       8693             8693    8512.000000  8510.000000
# unique       2          2                2            NaN          NaN
# top      False      False             True            NaN          NaN
# freq      5507       5683             4538            NaN          NaN
# mean       NaN        NaN              NaN       1.772195     1.947541
# std        NaN        NaN              NaN       2.736122     2.950822
# min        NaN        NaN              NaN       0.000000     0.000000
# 25%        NaN        NaN              NaN       0.000000     0.000000
# 50%        NaN        NaN              NaN       0.000000     0.000000
# 75%        NaN        NaN              NaN       3.871201     4.343805
# max        NaN        NaN              NaN       9.569971    10.302733
#
#        LogShoppingMall       LogSpa    LogVRDeck LogTotalSpending
# count      8485.000000  8510.000000  8505.000000      7785.000000
# unique             NaN          NaN          NaN              NaN
# top                NaN          NaN          NaN              NaN
# freq               NaN          NaN          NaN              NaN
# mean          1.638622     1.878394     1.796809         4.305709
# std           2.586336     2.785687     2.764405         3.700501
# min           0.000000     0.000000     0.000000         0.000000
# 25%           0.000000     0.000000     0.000000         0.000000
# 50%           0.000000     0.000000     0.000000         6.602588
# 75%           3.332205     4.094345     3.850148         7.304516
# max          10.064458    10.017218    10.091377        10.490941
#
# [11 rows x 36 columns]

# %% [markdown]
# #### Include All Data

# %%
df = train_data.copy()

# %%
X = df.drop(columns="Transported")
y = df["Transported"]

# %%
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))

# %%
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)

# %%
X_processed = feature_preprocessing.fit_transform(X)

# %%
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=1)
# Out:
# <style type="text/css">
# #T_11a7c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_11a7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11a7c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_11a7c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11a7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11a7c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_11a7c_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11a7c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_11a7c_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11a7c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_11a7c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11a7c_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_11a7c_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11a7c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_11a7c_row4_col1" class="data row4 col1" >(8693, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11a7c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_11a7c_row5_col1" class="data row5 col1" >(8693, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11a7c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_11a7c_row6_col1" class="data row6 col1" >(6085, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11a7c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_11a7c_row7_col1" class="data row7 col1" >(2608, 76)</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11a7c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_11a7c_row8_col1" class="data row8 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11a7c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_11a7c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_11a7c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_11a7c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_11a7c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_11a7c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_11a7c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_11a7c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_11a7c_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_11a7c_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_11a7c_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_11a7c_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_11a7c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_11a7c_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_11a7c_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_11a7c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_11a7c_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_11a7c_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_11a7c_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_11a7c_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_11a7c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_11a7c_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_11a7c_row19_col1" class="data row19 col1" >d3c6</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pc_workflow.compare_models()
# Out:
# <style type="text/css">
# #T_7efb5 th {
#   text-align: left;
# }
# #T_7efb5_row0_col0, #T_7efb5_row1_col0, #T_7efb5_row1_col1, #T_7efb5_row1_col2, #T_7efb5_row1_col3, #T_7efb5_row1_col4, #T_7efb5_row1_col5, #T_7efb5_row1_col6, #T_7efb5_row1_col7, #T_7efb5_row2_col0, #T_7efb5_row2_col1, #T_7efb5_row2_col2, #T_7efb5_row2_col3, #T_7efb5_row2_col4, #T_7efb5_row2_col5, #T_7efb5_row2_col6, #T_7efb5_row2_col7, #T_7efb5_row3_col0, #T_7efb5_row3_col1
row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_7efb5_row4_col1" class="data row4 col1" >0.7911</td>
#       <td id="T_7efb5_row4_col2" class="data row4 col2" >0.8738</td>
#       <td id="T_7efb5_row4_col3" class="data row4 col3" >0.7911</td>
#       <td id="T_7efb5_row4_col4" class="data row4 col4" >0.7920</td>
#       <td id="T_7efb5_row4_col5" class="data row4 col5" >0.7909</td>
#       <td id="T_7efb5_row4_col6" class="data row4 col6" >0.5821</td>
#       <td id="T_7efb5_row4_col7" class="data row4 col7" >0.5830</td>
#       <td id="T_7efb5_row4_col8" class="data row4 col8" >0.8950</td>
#     </tr>
#     <tr>
#       <th id="T_7efb5_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_7efb5_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_7efb5_row5_col1" class="data row5 col1" >0.7906</td>
#       <td id="T_7efb5_row5_col2" class="data row5 col2" >0.8675</td>
#       <td id="T_7efb5_row5_col3" class="data row5 col3" >0.7906</td>
#       <td id="T_7efb5_row5_col4" class="data row5 col4" >0.7910</td>
#       <t

# %% [markdown]
# A few things to note:
# - This is likely to overfit, there are redundant features.
# - This is slow, there are a lot of features
# - Only tree-based classifiers can really handle this sort of modeling.
# - Max accuracy is .8074

# %%
pc_workflow.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# note in Feature Importance:
# - Age appears to be an important variable
# - Total Spending is important, as are all of the other spending features
# - It uses the raw spending as more important than the logarithmic spending

# %% [markdown]
# ## What if we only use the log values for spending variables?

# %%
df = train_data.copy()
df.columns
# Out:
# Index(['PassengerNum', 'Age', 'HomePlanet', 'Destination', 'CabinDeck',
#        'CabinSide', 'CryoSleep', 'VIP', 'RoomService', 'FoodCourt',
#        'ShoppingMall', 'Spa', 'VRDeck', 'Transported', 'NameMissing',
#        'HomeMissing', 'DestinationMissing', 'CabinMissing', 'CryoMissing',
#        'VIPMissing', 'PartySize', 'FamilyGroupMember', 'CabinBin',
#        'TotalSpending', 'YesRoomService', 'YesFoodCourt', 'YesShoppingMall',
#        'YesSpa', 'YesVRDeck', 'YesTotalSpending', 'LogRoomService',
#        'LogFoodCourt', 'LogShoppingMall', 'LogSpa', 'LogVRDeck',
#        'LogTotalSpending'],
#       dtype='object')

# %%
df = train_data.copy()
X = df.drop(
    columns=["Transported", "RoomService", "FoodCourt", "ShoppingMall", "Spa", "VRDeck"]
)
y = df["Transported"]
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)
X_processed = feature_preprocessing.fit_transform(X)
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=2)
# Out:
# <style type="text/css">
# #T_02925_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_02925">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02925_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_02925_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02925_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02925_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_02925_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02925_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_02925_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02925_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_02925_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02925_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_02925_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_02925_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_02925_row4_col1" class="data row4 col1" >(8693, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_02925_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_02925_row5_col1" class="data row5 col1" >(8693, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_02925_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_02925_row6_col1" class="data row6 col1" >(6085, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_02925_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_02925_row7_col1" class="data row7 col1" >(2608, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_02925_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_02925_row8_col1" class="data row8 col1" >70</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_02925_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_02925_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_02925_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_02925_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_02925_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_02925_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_02925_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_02925_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_02925_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_02925_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_02925_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_02925_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_02925_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_02925_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_02925_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_02925_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_02925_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_02925_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_02925_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_02925_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_02925_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_02925_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_02925_row19_col1" class="data row19 col1" >252b</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pc_workflow.compare_models()
# Out:
# <style type="text/css">
# #T_ff0ac th {
#   text-align: left;
# }
# #T_ff0ac_row0_col0, #T_ff0ac_row0_col2, #T_ff0ac_row1_col0, #T_ff0ac_row1_col1, #T_ff0ac_row1_col3, #T_ff0ac_row1_col4, #T_ff0ac_row1_col5, #T_ff0ac_row1_col6, #T_ff0ac_row1_col7, #T_ff0ac_row2_col0, #T_ff0ac_row2_col1, #T_ff0ac_row2_col2, #T_ff0ac_row2_col3, #T_ff0ac_row2_col4, #T_ff0ac_row2_col5, #T_ff0ac_row2_col6, #T_ff0ac_row2_col7, #T_ff0ac_row3_col0, #T_ff0ac_row3_col1, #T_ff0ac_row3_col2, #T_ff0ac_row3_col3, #T_ff0ac_row3_col4, #T_ff0ac_row3_col5, #T_ff0ac_row3_col6, #T_ff0ac_row3_col7, #T_ff0ac_row4_col0, #T_ff0ac_row4_col1, #T_ff0ac_row4_col2, #T_ff0ac_row4_col3, #T_ff0ac_row4_col4, #T_ff0ac_row4_col5, #T_ff0ac_row4_col6, #T_ff0ac_row4_col7, #T_ff0ac_row5_col0, #T_ff0ac_row5_col1, #T_ff0ac_row5_col2, #T_ff0ac_row5_col3, #T_ff0ac_row5_col4, #T_ff0ac_row5_col5, #T_ff0ac_row5_col6, #T_ff0ac_row5_col7, #T_ff0ac_row6_col0, #T_ff0ac_row6_col1, #T_ff0ac_row6_col2, #T_ff0ac_row6_col3, #T_ff0ac_row6_col4, #T_ff0ac_row6_col5, #T_ff0ac_row6_col6, #T_ff0ac_row6_col7, #T_ff0ac_row7_col0, #T_ff0ac_row7_col1, #T_ff0ac_row7_col2, #T_ff0ac_row7_col3, #T_ff0ac_row7_col4, #T_ff0ac_row7_col5, #T_ff0ac_row7_col6, #T_ff0ac_row7_col7, #T_ff0ac_row8_col0, #T_ff0ac_row8_col1, #T_ff0ac_row8_col2, #T_ff0ac_row8_col3, #T_ff0ac_row8_col4, #T_ff0ac_row8_col5, #T_ff0ac_row8_col6, #T_ff0ac_row8_col7, #T_ff0ac_row9_col0, #T_ff0ac_row9_col1, #T_ff0ac_row9_col2, #T_ff0ac_row9_col3, #T_ff0ac_row9_col4, #T_ff0ac_row9_col5, #T_ff0ac_row9_col6, #T_ff0ac_row9_col7, #T_ff0ac_row10_col0, #T_ff0ac_row10_col1, #T_ff0ac_row10_col2, #T_ff0ac_row10_col3, #T_ff0ac_row10_col4, #T_ff0ac_row10_col5, #T_ff0ac_row10_col6, #T_ff0ac_row10_col7, #T_ff0ac_row11_col0, #T_ff0ac_row11_col1, #T_ff0ac_row11_col2, #T_ff0ac_row11_col3, #T_ff0ac_row11_col4, #T_ff0ac_row11_col5, #T_ff0ac_row11_col6, #T_ff0ac_row11_col7, #T_ff0ac_row12_col0, #T_ff0ac_row12_col1, #T_ff0ac_row12_col2, #T_ff0ac_row12_col3, #T_ff0ac_row12_col4, #T_ff0ac_row12_col5, #T_ff0ac_row12_col6, #T_ff0ac_row12_col7, #T_ff0ac_row13_col0, #T_ff0ac_row13_col1, #T_ff0ac_row13_col2, #T_ff0ac_row13_col3, #T_ff0ac_row13_col4, #T_ff0ac_row13_col5, #T_ff0ac_row13_col6, #T_ff0ac_row13_col7, #T_ff0ac_row14_col0, #T_ff0ac_row14_col1, #T_ff0ac_row14_col2, #T_ff0ac_row14_col3, #T_ff0ac_row14_col4, #T_ff0ac_row14_col5, #T_ff0ac_row14_col6, #T_ff0ac_row14_col7 {
#   text-align: left;
# }
# #T_ff0ac_row0_col1, #T_ff0ac_row0_col3, #T_ff0ac_row0_col4, #T_ff0ac_row0_col5, #T_ff0ac_row0_col6, #T_ff0ac_row0_col7, #T_ff0ac_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff0ac_row0_col8, #T_ff0ac_row1_col8, #T_ff0ac_row2_col8, #T_ff0ac_row3_col8, #T_ff0ac_row4_col8, #T_ff0ac_row5_col8, #T_ff0ac_row6_col8, #T_ff0ac_row7_col8, #T_ff0ac_row8_col8, #T_ff0ac_row9_col8, #T_ff0ac_row10_col8, #T_ff0ac_row11_col8, #T_ff0ac_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff0ac_row12_col8, #T_ff0ac_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff0ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff0ac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff0ac_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff0ac_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff0ac_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff0ac_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff0ac_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff0ac_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff0ac_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ff0ac_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff0ac_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_ff0ac_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ff0ac_row0_col1" class="data row0 col1" >0.8041</td>
#       <td id="T_ff0ac_row0_col2" class="data row0 col2" >0.8961</td>
#       <td id="T_ff0ac_row0_col3" class="data row0 col3" >0.8041</td>
#       <td id="T_ff0ac_row0_col4" class="data row0 col4" >0.8048</td>
#       <td id="T_ff0ac_row0_col5" class="data row0 col5" >0.8039</td>
#       <td id="T_ff0ac_row0_col6" class="data row0 col6" >0.6081</td>
#       <td id="T_ff0ac_row0_col7" class="data row0 col7" >0.6088</td>
#       <td id="T_ff0ac_row0_col8" class="data row0 col8" >0.4160</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ac_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_ff0ac_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ff0ac_row1_col1" class="data row1 col1" >0.8030</td>
#       <td id="T_ff0ac_row1_col2" class="data row1 col2" >0.8973</td>
#       <td id="T_ff0ac_row1_col3" class="data row1 col3" >0.8030</td>
#       <td id="T_ff0ac_row1_col4" class="data row1 col4" >0.8033</td>
#       <td id="T_ff0ac_row1_col5" class="data row1 col5" >0.8029</td>
#       <td id="T_ff0ac_row1_col6" class="data row1 col6" >0.6059</td>
#       <td id="T_ff0ac_row1_col7" class="data row1 col7" >0.6062</td>
#       <td id="T_ff0ac_row1_col8" class="data row1 col8" >1.0510</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ac_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_ff0ac_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff0ac_row2_col1" class="data row2 col1" >0.7970</td>
#       <td id="T_ff0ac_row2_col2" class="data row2 col2" >0.8951</td>
#       <td id="T_ff0ac_row2_col3" class="data row2 col3" >0.7970</td>
#       <td id="T_ff0ac_row2_col4" class="data row2 col4" >0.7975</td>
#       <td id="T_ff0ac_row2_col5" class="data row2 col5" >0.7970</td>
#       <td id="T_ff0ac_row2_col6" class="data row2 col6" >0.5941</td>
#       <td id="T_ff0ac_row2_col7" class="data row2 col7" >0.5945</td>
#       <td id="T_ff0ac_row2_col8" class="data row2 col8" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ac_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_ff0ac_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_ff0ac_row3_col1" class="data row3 col1" >0.7880</td>
#       <td id="T_ff0ac_row3_col2" class="data row3 col2" >0.8789</td>
#       <td id="T_ff0ac_row3_col3" class="data row3 col3" >0.7880</td>
#       <td id="T_ff0ac_row3_col4" class="data row3 col4" >0.7896</td>
#       <td id="T_ff0ac_row3_col5" class="data row3 col5" >0.7876</td>
#       <td id="T_ff0ac_row3_col6" class="data row3 col6" >0.5757</td>
#       <td id="T_ff0ac_row3_col7" class="data row3 col7" >0.5775</td>
#       <td id="T_ff0ac_row3_col8" class="data row3 col8" >0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ac_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_ff0ac_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_ff0ac_row4_col1" class="data row4 col1" >0.7877</td>
#       <td id="T_ff0ac_row4_col2" class="data row4 col2" >0.8662</td>
#       <td id="T_ff0ac_row4_col3" class="data row4 col3" >0.7877</td>
#       <td id="T_ff0ac_row4_col4" class="data row4 col4" >0.7909</td>
#       <td id="T_ff0ac_row4_col5" class="data row4 col5" >0.7872</td>
#       <td id="T_ff0ac_row4_col6" class="data row4 col6" >0.5756</td>
#       <td id="T_ff0ac_row4_col7" class="data row4 col7" >0.5787</td>
#       <td id="T_ff0ac_row4_col8" class="data row4 col8" >0.2350</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ac_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_ff0ac_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_ff0ac_row5_col1" class="data row5 col1" >0.7865</td>
#       <td id="T_ff0ac_row5_col2" class="data row5 col2" >0.8612</td>
#       <td id="T_ff0ac_row5_col3" class="data row5 col3" >0.7865</td>
#       <td id="T_ff0ac_row5_col4" class="data row5 col4" >0.7876</td>
#       <td id="T_

# %%
pc_workflow.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# This performs even better, but is very reliant on gradient boosted tree models. However, I do find it to be superior to using all features. However, one thing I notice is that I used Total Spending AND log total spending. let's remove this redundancy.

# %%
df = train_data.copy()
df.columns
# Out:
# Index(['PassengerNum', 'Age', 'HomePlanet', 'Destination', 'CabinDeck',
#        'CabinSide', 'CryoSleep', 'VIP', 'RoomService', 'FoodCourt',
#        'ShoppingMall', 'Spa', 'VRDeck', 'Transported', 'NameMissing',
#        'HomeMissing', 'DestinationMissing', 'CabinMissing', 'CryoMissing',
#        'VIPMissing', 'PartySize', 'FamilyGroupMember', 'CabinBin',
#        'TotalSpending', 'YesRoomService', 'YesFoodCourt', 'YesShoppingMall',
#        'YesSpa', 'YesVRDeck', 'YesTotalSpending', 'LogRoomService',
#        'LogFoodCourt', 'LogShoppingMall', 'LogSpa', 'LogVRDeck',
#        'LogTotalSpending'],
#       dtype='object')

# %%
df = train_data.copy()
X = df.drop(
    columns=[
        "Transported",
        "RoomService",
        "FoodCourt",
        "ShoppingMall",
        "Spa",
        "VRDeck",
        "TotalSpending",
    ]
)
y = df["Transported"]
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)
X_processed = feature_preprocessing.fit_transform(X)

# %%
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=3)
# Out:
# <style type="text/css">
# #T_519e2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_519e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_519e2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_519e2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_519e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_519e2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_519e2_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_519e2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_519e2_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_519e2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_519e2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_519e2_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_519e2_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_519e2_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_519e2_row4_col1" class="data row4 col1" >(8693, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_519e2_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_519e2_row5_col1" class="data row5 col1" >(8693, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_519e2_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_519e2_row6_col1" class="data row6 col1" >(6085, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_519e2_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_519e2_row7_col1" class="data row7 col1" >(2608, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_519e2_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_519e2_row8_col1" class="data row8 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_519e2_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_519e2_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_519e2_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_519e2_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_519e2_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_519e2_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_519e2_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_519e2_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_519e2_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_519e2_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_519e2_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_519e2_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_519e2_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_519e2_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_519e2_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_519e2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_519e2_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_519e2_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_519e2_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_519e2_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_519e2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_519e2_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_519e2_row19_col1" class="data row19 col1" >2222</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pc_workflow.compare_models()
# Out:
# <style type="text/css">
# #T_9f8c2 th {
#   text-align: left;
# }
# #T_9f8c2_row0_col0, #T_9f8c2_row1_col0, #T_9f8c2_row1_col1, #T_9f8c2_row1_col2, #T_9f8c2_row1_col3, #T_9f8c2_row1_col4, #T_9f8c2_row1_col5, #T_9f8c2_row1_col6, #T_9f8c2_row1_col7, #T_9f8c2_row2_col0, #T_9f8c2_row2_col1, #T_9f8c2_row2_col2, #T_9f8c2_row2_col3, #T_9f8c2_row2_col4, #T_9f8c2_row2_col5, #T_9f8c2_row2_col6, #T_9f8c2_row2_col7, #T_9f8c2_row3_col0, #T_9f8c2_row3_col1, #T_9f8c2_row3_col2, #T_9f8c2_row3_col3, #T_9f8c2_row3_col4, #T_9f8c2_row3_col5, #T_9f8c2_row3_col6, #T_9f8c2_row3_col7, #T_9f8c2_row4_col0, #T_9f8c2_row4_col1, #T_9f8c2_row4_col2, #T_9f8c2_row4_col3, #T_9f8c2_row4_col4, #T_9f8c2_row4_col5, #T_9f8c2_row4_col6, #T_9f8c2_row4_col7, #T_9f8c2_row5_col0, #T_9f8c2_row5_col1, #T_9f8c2_row5_col2, #T_9f8c2_row5_col3, #T_9f8c2_row5_col4, #T_9f8c2_row5_col5, #T_9f8c2_row5_col6, #T_9f8c2_row5_col7, #T_9f8c2_row6_col0, #T_9f8c2_row6_col1, #T_9f8c2_row6_col2, #T_9f8c2_row6_col3, #T_9f8c2_row6_col4, #T_9f8c2_row6_col5, #T_9f8c2_row6_col6, #T_9f8c2_row6_col7, #T_9f8c2_row7_col0, #T_9f8c2_row7_col1, #T_9f8c2_row7_col2, #T_9f8c2_row7_col3, #T_9f8c2_row7_col4, #T_9f8c2_row7_col5, #T_9f8c2_row7_col6, #T_9f8c2_row7_col7, #T_9f8c2_row8_col0, #T_9f8c2_row8_col1, #T_9f8c2_row8_col2, #T_9f8c2_row8_col3, #T_9f8c2_row8_col4, #T_9f8c2_row8_col5, #T_9f8c2_row8_col6, #T_9f8c2_row8_col7, #T_9f8c2_row9_col0, #T_9f8c2_row9_col1, #T_9f8c2_row9_col2, #T_9f8c2_row9_col3, #T_9f8c2_row9_col4, #T_9f8c2_row9_col5, #T_9f8c2_row9_col6, #T_9f8c2_row9_col7, #T_9f8c2_row10_col0, #T_9f8c2_row10_col1, #T_9f8c2_row10_col2, #T_9f8c2_row10_col3, #T_9f8c2_row10_col4, #T_9f8c2_row10_col5, #T_9f8c2_row10_col6, #T_9f8c2_row10_col7, #T_9f8c2_row11_col0, #T_9f8c2_row11_col1, #T_9f8c2_row11_col2, #T_9f8c2_row11_col3, #T_9f8c2_row11_col4, #T_9f8c2_row11_col5, #T_9f8c2_row11_col6, #T_9f8c2_row11_col7, #T_9f8c2_row12_col0, #T_9f8c2_row12_col1, #T_9f8c2_row12_col2, #T_9f8c2_row12_col3, #T_9f8c2_row12_col4, #T_9f8c2_row12_col5, #T_9f8c2_row12_col6, #T_9f8c2_row12_col7, #T_9f8c2_row13_col0, #T_9f8c2_row13_col1, #T_9f8c2_row13_col2, #T_9f8c2_row13_col3, #T_9f8c2_row13_col4, #T_9f8c2_row13_col5, #T_9f8c2_row13_col6, #T_9f8c2_row13_col7, #T_9f8c2_row14_col0, #T_9f8c2_row14_col1, #T_9f8c2_row14_col2, #T_9f8c2_row14_col3, #T_9f8c2_row14_col4, #T_9f8c2_row14_col5, #T_9f8c2_row14_col6, #T_9f8c2_row14_col7 {
#   text-align: left;
# }
# #T_9f8c2_row0_col1, #T_9f8c2_row0_col2, #T_9f8c2_row0_col3, #T_9f8c2_row0_col4, #T_9f8c2_row0_col5, #T_9f8c2_row0_col6, #T_9f8c2_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_9f8c2_row4_col1" class="data row4 col1" >0.7901</td>
#       <td id="T_9f8c2_row4_col2" class="data row4 col2" >0.8789</td>
#       <td id="T_9f8c2_row4_col3" class="data row4 col3" >0.7901</td>
#       <td id="T_9f8c2_row4_col4" class="data row4 col4" >0.7927</td>
#       <td id="T_9f8c2_row4_col5" class="data row4 col5" >0.7896</td>
#       <td id="T_9f8c2_row4_col6" class="data row4 col6" >0.5800</td>
#       <td id="T_9f8c2_row4_col7" class="data row4 col7" >0.5826</td>
#       <td id="T_9f8c2_row4_col8" class="data row4 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_9f8c2_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_9f8c2_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_9f8c2_row5_col1" class="data row5 col1" >0.7806</td>
#       <td id="T_9f8c2_row5_col2" class="data row5 col2" >0.8599</td>
#       <td id="T_9f8c2_row5_col3" class="data row5 col3" >0.7806</td>
#       <td id="T_9f8c2_row5_col4" class="data row5 col4" >0.7817</td>
#       <td id="T_

# %%
pc_workflow.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# I would say that this is our best performing model yet
#
# ## What happens if we remove total spending entirely and have the model rely solely on the individual spending variables?

# %%
df.columns
# Out:
# Index(['PassengerNum', 'Age', 'HomePlanet', 'Destination', 'CabinDeck',
#        'CabinSide', 'CryoSleep', 'VIP', 'RoomService', 'FoodCourt',
#        'ShoppingMall', 'Spa', 'VRDeck', 'Transported', 'NameMissing',
#        'HomeMissing', 'DestinationMissing', 'CabinMissing', 'CryoMissing',
#        'VIPMissing', 'PartySize', 'FamilyGroupMember', 'CabinBin',
#        'TotalSpending', 'YesRoomService', 'YesFoodCourt', 'YesShoppingMall',
#        'YesSpa', 'YesVRDeck', 'YesTotalSpending', 'LogRoomService',
#        'LogFoodCourt', 'LogShoppingMall', 'LogSpa', 'LogVRDeck',
#        'LogTotalSpending'],
#       dtype='object')

# %%
df = train_data.copy()
X = df.drop(
    columns=[
        "Transported",
        "RoomService",
        "FoodCourt",
        "ShoppingMall",
        "Spa",
        "VRDeck",
        "TotalSpending",
        "LogTotalSpending",
    ]
)
y = df["Transported"]
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)
X_processed = feature_preprocessing.fit_transform(X)

# %%
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=3)
# Out:
# <style type="text/css">
# #T_d7fa1_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d7fa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7fa1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d7fa1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7fa1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7fa1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d7fa1_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d7fa1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7fa1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d7fa1_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_d
row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_5ab51_row2_col1" class="data row2 col1" >0.7933</td>
#       <td id="T_5ab51_row2_col2" class="data row2 col2" >0.8832</td>
#       <td id="T_5ab51_row2_col3" class="data row2 col3" >0.7933</td>
#       <td id="T_5ab51_row2_col4" class="data row2 col4" >0.7934</td>
#       <td id="T_5ab51_row2_col5" class="data row2 col5" >0.7932</td>
#       <td id="T_5ab51_row2_col6" class="data row2 col6" >0.5865</td>
#       <td id="T_5ab51_row2_col7" class="data row2 col7" >0.5866</td>
#       <td id="T_5ab51_row2_col8" class="data row2 col8" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_5ab51_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_5ab51_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_5ab51_row3_col1" class="data row3 col1" >0.7908</td>
#       <td id="T_5ab51_row3_col2" class="data row3 col2" >0.8768</td>
#       <td id="T_5ab51_row3_col3" class="data row3 col3" >0.7908</td>
#       <td id="T_5ab51_row3_col4" class="data row3 col4" >0.7923</td>
#       <td id="T_5ab51_row3_col5" class="data row3 col5" >0.7905</td>
#       <td id="T_5ab51_row3_col6" class="data row3 col6" >0.5814</td>
#       <td id="T_5ab51_row3_col7" class="data row3 col7" >0.5829</td>
#       <td id="T_5ab51_row3_col8" class="data row3 col8" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_5ab51_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_5ab51_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_5ab51_row4_col1" class="data row4 col1" >0.7882</td>
#       <td id="T_5ab51_row4_col2" class="data row4 col2" >0.8642</td>
#       <td id="T_5ab51_row4_col3" class="data row4 col3" >0.7882</td>
#       <td id="T_5ab51_row4_col4" class="data row4 col4" >0.7912</td>
#       <td id="T_5ab51_row4_col5" class="data row4 col5" >0.7877</td>
#       <td id="T_5ab51_row4_col6" class="data row4 col6" >0.5766</td>
#       <td id="T_5ab51_row4_col7" class="data row4 col7" >0.5795</td>
#       <td id="T_5ab51_row4_col8" class="data row4 col8" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_5ab51_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_5ab51_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_5ab51_row5_col1" class="data row5 col1" >0.7803</td>
#       <td id="T_5ab51_row5_col2" class="data row5 col2" >0.8596</td>
#       <td id="T_5ab51_row5_col3" class="data row5 col3" >0.7803</td>
#       <td id="T_5ab51_row5_col4" class="data row5 col4" >0.7811</td>
#       <td id="T_

# %%
pc_workflow.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # What if I use the non-logarithmic spending variables?

# %%
df = train_data.copy()
X = df.drop(
    columns=[
        "Transported",
        "LogRoomService",
        "LogFoodCourt",
        "LogShoppingMall",
        "LogSpa",
        "LogVRDeck",
        "LogTotalSpending",
    ]
)
y = df["Transported"]
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)
X_processed = feature_preprocessing.fit_transform(X)

# %%
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=5)
# Out:
# <style type="text/css">
# #T_b9edb_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b9edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9edb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b9edb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9edb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9edb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b9edb_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9edb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b9edb_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9edb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b9edb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9edb_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_b9edb_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9edb_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_b9edb_row4_col1" class="data row4 col1" >(8693, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9edb_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_b9edb_row5_col1" class="data row5 col1" >(8693, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9edb_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_b9edb_row6_col1" class="data row6 col1" >(6085, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9edb_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_b9edb_row7_col1" class="data row7 col1" >(2608, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9edb_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_b9edb_row8_col1" class="data row8 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9edb_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_b9edb_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b9edb_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_b9edb_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b9edb_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_b9edb_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b9edb_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_b9edb_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b9edb_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_b9edb_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b9edb_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_b9edb_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b9edb_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_b9edb_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b9edb_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_b9edb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b9edb_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_b9edb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b9edb_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_b9edb_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b9edb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b9edb_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_b9edb_row19_col1" class="data row19 col1" >330c</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pc_workflow.compare_models()
# Out:
# <style type="text/css">
# #T_4c15c th {
#   text-align: left;
# }
# #T_4c15c_row0_col0, #T_4c15c_row1_col0, #T_4c15c_row1_col1, #T_4c15c_row1_col2, #T_4c15c_row1_col3, #T_4c15c_row1_col4, #T_4c15c_row1_col5, #T_4c15c_row1_col6, #T_4c15c_row1_col7, #T_4c15c_row2_col0, #T_4c15c_row2_col1, #T_4c15c_row2_col2, #T_4c15c_row2_col3, #T_4c15c_row2_col4, #T_4c15c_row2_col5, #T_4c15c_row2_col6, #T_4c15c_row2_col7, #T_4c15c_row3_col0, #T_4c15c_row3_col1, #T_4c15c_row3_col2, #T_4c15c_row3_col3, #T_4c15c_row3_col4, #T_4c15c_row3_col5, #T_4c15c_row3_col6, #T_4c15c_row3_col7, #T_4c15c_row4_col0, #T_4c15c_row4_col1, #T_4c15c_row4_col2, #T_4c15c_row4_col3, #T_4c15c_row4_col4, #T_4c15c_row4_col5, #T_4c15c_row4_col6, #T_4c15c_row4_col7, #T_4c15c_row5_col0, #T_4c15c_row5_col1, #T_4c15c_row5_col2, #T_4c15c_row5_col3, #T_4c15c_row5_col4, #T_4c15c_row5_col5, #T_4c15c_row5_col6, #T_4c15c_row5_col7, #T_4c15c_row6_col0, #T_4c15c_row6_col1, #T_4c15c_row6_col2, #T_4c15c_row6_col3, #T_4c15c_row6_col4, #T_4c15c_row6_col5, #T_4c15c_row6_col6, #T_4c15c_row6_col7, #T_4c15c_row7_col0, #T_4c15c_row7_col1, #T_4c15c_row7_col2, #T_4c15c_row7_col3, #T_4c15c_row7_col4, #T_4c15c_row7_col5, #T_4c15c_row7_col6, #T_4c15c_row7_col7, #T_4c15c_row8_col0, #T_4c15c_row8_col1, #T_4c15c_row8_col2, #T_4c15c_row8_col3, #T_4c15c_row8_col4, #T_4c15c_row8_col5, #T_4c15c_row8_col6, #T_4c15c_row8_col7, #T_4c15c_row9_col0, #T_4c15c_row9_col1, #T_4c15c_row9_col2, #T_4c15c_row9_col3, #T_4c15c_row9_col4, #T_4c15c_row9_col5, #T_4c15c_row9_col6, #T_4c15c_row9_col7, #T_4c15c_row10_col0, #T_4c15c_row10_col1, #T_4c15c_row10_col2, #T_4c15c_row10_col3, #T_4c15c_row10_col4, #T_4c15c_row10_col5, #T_4c15c_row10_col6, #T_4c15c_row10_col7, #T_4c15c_row11_col0, #T_4c15c_row11_col1, #T_4c15c_row11_col2, #T_4c15c_row11_col3, #T_4c15c_row11_col4, #T_4c15c_row11_col5, #T_4c15c_row11_col6, #T_4c15c_row11_col7, #T_4c15c_row12_col0, #T_4c15c_row12_col1, #T_4c15c_row12_col2, #T_4c15c_row12_col3, #T_4c15c_row12_col4, #T_4c15c_row12_col5, #T_4c15c_row12_col6, #T_4c15c_row12_col7, #T_4c15c_row13_col0, #T_4c15c_row13_col1, #T_4c15c_row13_col2, #T_4c15c_row13_col3, #T_4c15c_row13_col4, #T_4c15c_row13_col5, #T_4c15c_row13_col6, #T_4c15c_row13_col7, #T_4c15c_row14_col0, #T_4c15c_row14_col1, #T_4c15c_row14_col2, #T_4c15c_row14_col3, #T_4c15c_row14_col4, #T_4c15c_row14_col5, #T_4c15c_row14_col6, #T_4c15c_row14_col7 {
#   text-align: left;
# }
# #T_4c15c_row0_col1, #T_4c15c_row0_col2, #T_4c15c_row0_col3, #T_4c15c_row0_col4, #T_4c15c_row0_col5, #T_4c15c_row0_col6, #T_4c15c_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4c15c_row0_col8, #T_4c15c_row1_col8, #T_4c15c_row2_col8, #T_4c15c_row3_col8, #T_4c15c_row4_col8, #T_4c15c_row5_col8, #T_4c15c_row6_col8, #T_4c15c_row7_col8, #T_4c15c_row8_col8, #T_4c15c_row9_col8, #T_4c15c_row10_col8, #T_4c15c_row12_col8, #T_4c15c_row13_col8, #T_4c15c_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4c15c_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4c15c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c15c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4c15c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4c15c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4c15c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4c15c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4c15c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4c15c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4c15c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4c15c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c15c_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_4c15c_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4c15c_row0_col1" class="data row0 col1" >0.8051</td>
#       <td id="T_4c15c_row0_col2" class="data row0 col2" >0.8960</td>
#       <td id="T_4c15c_row0_col3" class="data row0 col3" >0.8051</td>
#       <td id="T_4c15c_row0_col4" class="data row0 col4" >0.8052</td>
#       <td id="T_4c15c_row0_col5" class="data row0 col5" >0.8051</td>
#       <td id="T_4c15c_row0_col6" class="data row0 col6" >0.6102</td>
#       <td id="T_4c15c_row0_col7" class="data row0 col7" >0.6103</td>
#       <td id="T_4c15c_row0_col8" class="data row0 col8" >0.9770</td>
#     </tr>
#     <tr>
#       <th id="T_4c15c_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_4c15c_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_4c15c_row1_col1" class="data row1 col1" >0.8003</td>
#       <td id="T_4c15c_row1_col2" class="data row1 col2" >0.8938</td>
#       <td id="T_4c15c_row1_col3" class="data row1 col3" >0.8003</td>
#       <td id="T_4c15c_row1_col4" class="data row1 col4" >0.8005</td>
#       <td id="T_4c15c_row1_col5" class="data row1 col5" >0.8003</td>
#       <td id="T_4c15c_row1_col6" class="data row1 col6" >0.6006</td>
#       <td id="T_4c15c_row1_col7" class="data row1 col7" >0.6008</td>
#       <td id="T_4c15c_row1_col8" class="data row1 col8" >0.3450</td>
#     </tr>
#     <tr>
#       <th id="T_4c15c_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_4c15c_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4c15c_row2_col1" class="data row2 col1" >0.7979</td>
#       <td id="T_4c15c_row2_col2" class="data row2 col2" >0.8893</td>
#       <td id="T_4c15c_row2_col3" class="data row2 col3" >0.7979</td>
#       <td id="T_4c15c_row2_col4" class="data row2 col4" >0.7984</td>
#       <td id="T_4c15c_row2_col5" class="data row2 col5" >0.7978</td>
#       <td id="T_4c15c_row2_col6" class="data row2 col6" >0.5958</td>
#       <td id="T_4c15c_row2_col7" class="data row2 col7" >0.5963</td>
#       <td id="T_4c15c_row2_col8" class="data row2 col8" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_4c15c_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_4c15c_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_4c15c_row3_col1" class="data row3 col1" >0.7898</td>
#       <td id="T_4c15c_row3_col2" class="data row3 col2" >0.8662</td>
#       <td id="T_4c15c_row3_col3" class="data row3 col3" >0.7898</td>
#       <td id="T_4c15c_row3_col4" class="data row3 col4" >0.7930</td>
#       <td id="T_4c15c_row3_col5" class="data row3 col5" >0.7893</td>
#       <td id="T_4c15c_row3_col6" class="data row3 col6" >0.5799</td>
#       <td id="T_4c15c_row3_col7" class="data row3 col7" >0.5830</td>
#       <td id="T_4c15c_row3_col8" class="data row3 col8" >0.2100</td>
#     </tr>
#     <tr>
#       <th id="T_4c15c_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_4c15c_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_4c15c_row4_col1" class="data row4 col1" >0.7883</td>
#       <td id="T_4c15c_row4_col2" class="data row4 col2" >0.8721</td>
#       <td id="T_4c15c_row4_col3" class="data row4 col3" >0.7883</td>
#       <td id="T_4c15c_row4_col4" class="data row4 col4" >0.7886</td>
#       <td id="T_4c15c_row4_col5" class="data row4 col5" >0.7883</td>
#       <td id="T_4c15c_row4_col6" class="data row4 col6" >0.5766</td>
#       <td id="T_4c15c_row4_col7" class="data row4 col7" >0.5769</td>
#       <td id="T_4c15c_row4_col8" class="data row4 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_4c15c_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_4c15c_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_4c15c_row5_col1" class="data row5 col1" >0.7864</td>
#       <td id="T_4c15c_row5_col2" class="data row5 col2" >0.8764</td>
#       <td id="T_4c15c_row5_col3" class="data row5 col3" >0.7864</td>
#       <td id="T_4c15c_row5_col4" class="data row5 col4" >0.7865</td>
#       <td id="T_

# %% [markdown]
# ## Lastly, let's try again, but this time, not including total spending, nor including the logarithmic spending variables

# %%
df = train_data.copy()

# %%
X = df.drop(
    columns=[
        "Transported",
        "TotalSpending",
        "LogRoomService",
        "LogFoodCourt",
        "LogShoppingMall",
        "LogSpa",
        "LogVRDeck",
        "LogTotalSpending",
        "LogTotalSpending",
    ]
)
y = df["Transported"]

# %%
numerical_columns = list(X.select_dtypes(include="number").drop(columns="CabinBin"))
categorical_columns = list(X.select_dtypes(include=["object"]))

# %%
set_config(transform_output="pandas")

cat_pipeline = Pipeline([("one_hot", OneHotEncoder(sparse_output=False))])
num_pipeline = Pipeline(
    [
        ("imputer", IterativeImputer(random_state=0)),
        ("scaler", StandardScaler()),
    ]
)
ord_pipeline = Pipeline(
    [
        ("oe", OrdinalEncoder()),
        ("imputer", IterativeImputer(random_state=0)),
        ("rounder", Rounder(decimals=0)),
    ]
)
feature_preprocessing = ColumnTransformer(
    [
        ("cat", cat_pipeline, categorical_columns),
        ("num", num_pipeline, numerical_columns),
        ("ord", ord_pipeline, ["CabinBin"]),
    ],
    verbose_feature_names_out=False,
)

# %%
X_processed = feature_preprocessing.fit_transform(X)

# %%
pc_workflow = ClassificationExperiment()
pc_workflow.setup(X_processed, target=y, session_id=6)
# Out:
# <style type="text/css">
# #T_44cc3_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44cc3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44cc3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_44cc3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44cc3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44cc3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_44cc3_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44cc3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_44cc3_row1_col1" class="data row1 col1" >Transported</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44cc3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_44cc3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44cc3_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_44cc3_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44cc3_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_44cc3_row4_col1" class="data row4 col1" >(8693, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44cc3_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_44cc3_row5_col1" class="data row5 col1" >(8693, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44cc3_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_44cc3_row6_col1" class="data row6 col1" >(6085, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44cc3_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_44cc3_row7_col1" class="data row7 col1" >(2608, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44cc3_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_44cc3_row8_col1" class="data row8 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44cc3_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_44cc3_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_44cc3_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_44cc3_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_44cc3_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_44cc3_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_44cc3_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_44cc3_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_44cc3_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_44cc3_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_44cc3_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_44cc3_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_44cc3_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_44cc3_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_44cc3_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_44cc3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_44cc3_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_44cc3_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_44cc3_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_44cc3_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_44cc3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_44cc3_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_44cc3_row19_col1" class="data row19 col1" >7ea1</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pc_workflow.compare_models()
# Out:
# <style type="text/css">
# #T_2982f th {
#   text-align: left;
# }
# #T_2982f_row0_col0, #T_2982f_row1_col0, #T_2982f_row1_col1, #T_2982f_row1_col2, #T_2982f_row1_col3, #T_2982f_row1_col4, #T_2982f_row1_col5, #T_2982f_row1_col6, #T_2982f_row1_col7, #T_2982f_row2_col0, #T_2982f_row2_col1, #T_2982f_row2_col2, #T_2982f_row2_col3, #T_2982f_row2_col4, #T_2982f_row2_col5, #T_2982f_row2_col6, #T_2982f_row2_col7, #T_2982f_row3_col0, #T_2982f_row3_col1, #T_2982f_row3_col2, #T_2982f_row3_col3, #T_2982f_row3_col4, #T_2982f_row3_col5, #T_2982f_row3_col6, #T_2982f_row3_col7, #T_2982f_row4_col0, #T_2982f_row4_col1, #T_2982f_row4_col2, #T_2982f_row4_col3, #T_2982f_row4_col4, #T_2982f_row4_col5, #T_2982f_row4_col6, #T_2982f_row4_col7, #T_2982f_row5_col0, #T_2982f_row5_col1, #T_2982f_row5_col2, #T_2982f_row5_col3, #T_2982f_row5_col4, #T_2982f_row5_col5, #T_2982f_row5_col6, #T_2982f_row5_col7, #T_2982f_row6_col0, #T_2982f_row6_col1, #T_2982f_row6_col2, #T_2982f_row6_col3, #T_2982f_row6_col4, #T_2982f_row6_col5, #T_2982f_row6_col6, #T_2982f_row6_col7, #T_2982f_row7_col0, #T_2982f_row7_col1, #T_2982f_row7_col2, #T_2982f_row7_col3, #T_2982f_row7_col4, #T_2982f_row7_col5, #T_2982f_row7_col6, #T_2982f_row7_col7, #T_2982f_row8_col0, #T_2982f_row8_col1, #T_2982f_row8_col2, #T_2982f_row8_col3, #T_2982f_row8_col4, #T_2982f_row8_col5, #T_2982f_row8_col6, #T_2982f_row8_col7, #T_2982f_row9_col0, #T_2982f_row9_col1, #T_2982f_row9_col2, #T_2982f_row9_col3, #T_2982f_row9_col4, #T_2982f_row9_col5, #T_2982f_row9_col6, #T_2982f_row9_col7, #T_2982f_row10_col0, #T_2982f_row10_col1, #T_2982f_row10_col2, #T_2982f_row10_col3, #T_2982f_row10_col4, #T_2982f_row10_col5, #T_2982f_row10_col6, #T_2982f_row10_col7, #T_2982f_row11_col0, #T_2982f_row11_col1, #T_2982f_row11_col2, #T_2982f_row11_col3, #T_2982f_row11_col4, #T_2982f_row11_col5, #T_2982f_row11_col6, #T_2982f_row11_col7, #T_2982f_row12_col0, #T_2982f_row12_col1, #T_2982f_row12_col2, #T_2982f_row12_col3, #T_2982f_row12_col4, #T_2982f_row12_col5, #T_2982f_row12_col6, #T_2982f_row12_col7, #T_2982f_row13_col0, #T_2982f_row13_col1, #T_2982f_row13_col2, #T_2982f_row13_col3, #T_2982f_row13_col4, #T_2982f_row13_col5, #T_2982f_row13_col6, #T_2982f_row13_col7, #T_2982f_row14_col0, #T_2982f_row14_col1, #T_2982f_row14_col2, #T_2982f_row14_col3, #T_2982f_row14_col4, #T_2982f_row14_col5, #T_2982f_row14_col6, #T_2982f_row14_col7 {
#   text-align: left;
# }
# #T_2982f_row0_col1, #T_2982f_row0_col2, #T_2982f_row0_col3, #T_2982f_row0_col4, #T_2982f_row0_col5, #T_2982f_row0_col6, #T_2982f_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2982f_row0_col8, #T_2982f_row1_col8, #T_2982f_row2_col8, #T_2982f_row3_col8, #T_2982f_row4_col8, #T_2982f_row5_col8, #T_2982f_row6_col8, #T_2982f_row7_col8, #T_2982f_row8_col8, #T_2982f_row9_col8, #T_2982f_row10_col8, #T_2982f_row11_col8, #T_2982f_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2982f_row12_col8, #T_2982f_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2982f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2982f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2982f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2982f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2982f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2982f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2982f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2982f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2982f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_2982f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2982f_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_2982f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2982f_row0_col1" class="data row0 col1" >0.8066</td>
#       <td id="T_2982f_row0_col2" class="data row0 col2" >0.8952</td>
#       <td id="T_2982f_row0_col3" class="data row0 col3" >0.8066</td>
#       <td id="T_2982f_row0_col4" class="data row0 col4" >0.8070</td>
#       <td id="T_2982f_row0_col5" class="data row0 col5" >0.8065</td>
#       <td id="T_2982f_row0_col6" class="data row0 col6" >0.6131</td>
#       <td id="T_2982f_row0_col7" class="data row0 col7" >0.6135</td>
#       <td id="T_2982f_row0_col8" class="data row0 col8" >0.9420</td>
#     </tr>
#     <tr>
#       <th id="T_2982f_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_2982f_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_2982f_row1_col1" class="data row1 col1" >0.8026</td>
#       <td id="T_2982f_row1_col2" class="data row1 col2" >0.8922</td>
#       <td id="T_2982f_row1_col3" class="data row1 col3" >0.8026</td>
#       <td id="T_2982f_row1_col4" class="data row1 col4" >0.8034</td>
#       <td id="T_2982f_row1_col5" class="data row1 col5" >0.8025</td>
#       <td id="T_2982f_row1_col6" class="data row1 col6" >0.6051</td>
#       <td id="T_2982f_row1_col7" class="data row1 col7" >0.6059</td>
#       <td id="T_2982f_row1_col8" class="data row1 col8" >0.3930</td>
#     </tr>
#     <tr>
#       <th id="T_2982f_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_2982f_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2982f_row2_col1" class="data row2 col1" >0.7974</td>
#       <td id="T_2982f_row2_col2" class="data row2 col2" >0.8870</td>
#       <td id="T_2982f_row2_col3" class="data row2 col3" >0.7974</td>
#       <td id="T_2982f_row2_col4" class="data row2 col4" >0.7976</td>
#       <td id="T_2982f_row2_col5" class="data row2 col5" >0.7973</td>
#       <td id="T_2982f_row2_col6" class="data row2 col6" >0.5947</td>
#       <td id="T_2982f_row2_col7" class="data row2 col7" >0.5950</td>
#       <td id="T_2982f_row2_col8" class="data row2 col8" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_2982f_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_2982f_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_2982f_row3_col1" class="data row3 col1" >0.7918</td>
#       <td id="T_2982f_row3_col2" class="data row3 col2" >0.8771</td>
#       <td id="T_2982f_row3_col3" class="data row3 col3" >0.7918</td>
#       <td id="T_2982f_row3_col4" class="data row3 col4" >0.7927</td>
#       <td id="T_2982f_row3_col5" class="data row3 col5" >0.7916</td>
#       <td id="T_2982f_row3_col6" class="data row3 col6" >0.5834</td>
#       <td id="T_2982f_row3_col7" class="data row3 col7" >0.5844</td>
#       <td id="T_2982f_row3_col8" class="data row3 col8" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_2982f_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_2982f_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_2982f_row4_col1" class="data row4 col1" >0.7910</td>
#       <td id="T_2982f_row4_col2" class="data row4 col2" >0.8759</td>
#       <td id="T_2982f_row4_col3" class="data row4 col3" >0.7910</td>
#       <td id="T_2982f_row4_col4" class="data row4 col4" >0.7918</td>
#       <td id="T_2982f_row4_col5" class="data row4 col5" >0.7907</td>
#       <td id="T_2982f_row4_col6" class="data row4 col6" >0.5818</td>
#       <td id="T_2982f_row4_col7" class="data row4 col7" >0.5826</td>
#       <td id="T_2982f_row4_col8" class="data row4 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_2982f_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_2982f_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_2982f_row5_col1" class="data row5 col1" >0.7870</td>
#       <td id="T_2982f_row5_col2" class="data row5 col2" >0.8651</td>
#       <td id="T_2982f_row5_col3" class="data row5 col3" >0.7870</td>
#       <td id="T_2982f_row5_col4" class="data row5 col4" >0.7897</td>
#       <td id="T_

# %%
pc_workflow.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Conclusions
#
# - All models performed somewhat similarly,
# - Tree-based models performed the best: LightGBM and the GradientBoostingClassifier typically performed the highest with respect to accuracy. Followed by XGBoost and Random Forest.
# - Logistic Regression varied in its performance, performaing best with all of the information (however this is potentially evidence of overfitting and not generalizable performance)
# - My approach based on these results will be do optimize a variety of these models and create an ensemble voting model.
# - Overall, I recommend a tree-based model as the primary method with all combinations of features (but no total spending feature)
